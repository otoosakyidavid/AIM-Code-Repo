# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.6/dist-packages (0.2.7)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from lazypredict) (7.1.2)

# %%
import pandas as pd
import numpy as np
import lazypredict
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor,LazyClassifier

# %%
df = pd.read_csv('/content/drive/My Drive/datasets/mercedes.csv')
df.head()
# Out:
#    ID      y  X0 X1  X2 X3 X4  ... X378 X379 X380  X382  X383  X384  X385
# 0   0 130.81   k  v  at  a  d  ...    0    0    0     0     0     0     0
# 1   6  88.53   k  t  av  e  d  ...    0    0    0     0     0     0     0
# 2   7  76.26  az  w   n  c  d  ...    0    0    0     1     0     0     0
# 3   9  80.62  az  t   n  f  d  ...    0    0    0     0     0     0     0
# 4  13  78.02  az  v   n  f  d  ...    0    0    0     0     0     0     0
#
# [5 rows x 378 columns]

# %%
X = df.drop(['y'], axis=1)
Y = df['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None,predictions=True)
models,pred = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 39/39 [00:01<00:00, 37.54it/s]
# [08:17:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                R-Squared  RMSE  Time Taken
# Model
# KNeighborsRegressor                 0.97  0.13        0.01
# AdaBoostRegressor                   0.97  0.14        0.07
# ExtraTreesRegressor                 0.96  0.16        0.08
# NuSVR                               0.95  0.16        0.01
# SVR                                 0.95  0.17        0.01
# GradientBoostingRegressor           0.94  0.18        0.07
# XGBRegressor                        0.94  0.18        0.03
# RandomForestRegressor               0.94  0.19        0.16
# BaggingRegressor                    0.93  0.20        0.02
# HistGradientBoostingRegressor       0.92  0.22        0.07
# LGBMRegressor                       0.92  0.22        0.02
# MLPRegressor                        0.91  0.22        0.17
# ExtraTreeRegressor                  0.87  0.27        0.00
# DecisionTreeRegressor               0.87  0.27        0.00
# SGDRegressor                        0.86  0.29        0.01
# LinearSVR                           0.86  0.29        0.02
# BayesianRidge                       0.85  0.29        0.00
# Ridge                               0.85  0.30        0.01
# RidgeCV                             0.85  0.30        0.01
# LarsCV                              0.85  0.30        0.02
# ElasticNetCV                        0.85  0.30        0.04
# LassoLarsCV                         0.85  0.30        0.03
# LassoCV                             0.85  0.30        0.06
# OrthogonalMatchingPursuitCV         0.85  0.30        0.01
# TransformedTargetRegressor          0.84  0.30        0.01
# LinearRegression                    0.84  0.30        0.01
# Lars                                0.84  0.30        0.01
# HuberRegressor                      0.84  0.30        0.01
# RANSACRegressor                     0.83  0.31        0.01
# LassoLarsIC                         0.83  0.31        0.01
# PassiveAggressiveRegressor          0.75  0.38        0.01
# OrthogonalMatchingPursuit           0.55  0.51        0.01
# ElasticNet                          0.25  0.66        0.01
# GaussianProcessRegressor            0.14  0.71        0.01
# DummyRegressor                     -0.01  0.77        0.00
# Lasso                              -0.01  0.77        0.01
# LassoLars                          -0.01  0.77        0.01
# KernelRidge                        -0.76  1.01        0.01

# %%
pred
# Out:
#     AdaBoostRegressor  BaggingRegressor  ...  XGBRegressor  LGBMRegressor
# 0                2.00              2.00  ...          1.76           1.71
# 1                1.00              1.50  ...          1.03           1.37
# 2                2.00              1.90  ...          1.69           1.71
# 3                1.00              1.10  ...          0.99           0.92
# 4                1.00              1.00  ...          1.00           1.03
# ..                ...               ...  ...           ...            ...
# 84               1.00              1.00  ...          0.92           0.95
# 85               2.00              2.00  ...          1.94           1.97
# 86               2.00              2.00  ...          2.02           1.97
# 87               0.00              0.00  ...          0.00           0.06
# 88               1.03              1.60  ...          1.46           1.68
#
# [89 rows x 38 columns]

# %%
from sklearn.datasets import load_wine

data = load_wine()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =0)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None,predictions=True)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 51.70it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LinearSVC                          1.00  ...        0.01
# ExtraTreesClassifier               1.00  ...        0.08
# LogisticRegression                 1.00  ...        0.01
# Perceptron                         1.00  ...        0.01
# QuadraticDiscriminantAnalysis      1.00  ...        0.01
# KNeighborsClassifier               1.00  ...        0.01
# PassiveAggressiveClassifier        1.00  ...        0.01
# NuSVC                              1.00  ...        0.01
# RidgeClassifier                    1.00  ...        0.01
# RidgeClassifierCV                  1.00  ...        0.01
# SVC                                1.00  ...        0.01
# CalibratedClassifierCV             1.00  ...        0.03
# SGDClassifier                      0.98  ...        0.01
# LinearDiscriminantAnalysis         0.98  ...        0.01
# BaggingClassifier                  0.98  ...        0.02
# NearestCentroid                    0.98  ...        0.01
# RandomForestClassifier             0.98  ...        0.13
# XGBClassifier                      0.96  ...        0.04
# LGBMClassifier                     0.94  ...        0.03
# LabelSpreading                     0.94  ...        0.01
# LabelPropagation                   0.94  ...        0.01
# GaussianNB                         0.94  ...        0.01
# DecisionTreeClassifier             0.93  ...        0.01
# BernoulliNB                        0.91  ...        0.01
# AdaBoostClassifier                 0.89  ...        0.07
# ExtraTreeClassifier                0.89  ...        0.01
# CheckingClassifier                 0.35  ...        0.01
# DummyClassifier                    0.35  ...        0.01
#
# [28 rows x 5 columns]

# %%
predictions
# Out:
#     AdaBoostClassifier  BaggingClassifier  ...  XGBClassifier  LGBMClassifier
# 0                    2                  2  ...              2               2
# 1                    1                  1  ...              1               1
# 2                    1                  2  ...              2               2
# 3                    1                  1  ...              1               1
# 4                    1                  1  ...              1               1
# ..                 ...                ...  ...            ...             ...
# 84                   1                  1  ...              1               1
# 85                   2                  2  ...              2               2
# 86                   2                  2  ...              2               2
# 87                   0                  0  ...              0               0
# 88                   2                  2  ...              2               2
#
# [89 rows x 28 columns]
